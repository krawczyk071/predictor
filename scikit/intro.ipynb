# %%
import pandas as pd

# %%
https://github.com/openfootball/awesome-football
https://github.com/jokecamp/FootballData

# RapidAPI
https://api-sports.io/
https://github.com/elenasport/apisports

# Predictions
https://boggio-analytics.com/fp-api/


# kaggle
https://www.kaggle.com/datasets/ajinkyablaze/football-manager-data
https://www.kaggle.com/datasets/stefanoleone992/ea-sports-fc-24-complete-player-dataset

# %%
PROFILE
seria5
h2h 3 sezony
ustawienie vs ustawienie przeciwnika, styl gry (opta radars) (ilosc podan,ilosc strzalow), quality index
https://www.whoscored.com/Matches/1775718/Preview/Europe-Europa-League-2023-2024-Liverpool-Union-St-Gilloise
miejsce w tabeli
home away
strzelane gole,puszczane gole
jak dlugo trener
Coach and referee stats
kontuzja gwiazdy
przerwa od ostatniego meczu
prev game oponent
*odds market, fotmob votes - jak wplywa popularnosc betu na jego cene -moze roznica miedzy pinacle a b365
stage/etap sezonu, exp points needed - jaki target utrzymanie,mistrz,CL
czy dobry bramkarz
transfermarkt
attendance against - czy przeciwnik jest ciekawy BOOL - 1srednialigowa 2przeciwkonam

GF GA Possession ExG

BASIC - 3 poziomy danych do podobienst stylow
pointsH/A Sh SoT GA GF Fls Off

# %%
MATCHdata

Possession
Passing Accuracy
Shots on Target
Saves
Cards

Fouls
Corners
Crosses
Touches

Tackles
Interceptions
Aerials Won
Clearances

Offsides
Goal Kicks
Throw Ins
Long Balls

# %%
TODO
opta style graph laga speed/ilosc podan
laga=PrgP/PrgC;Launched_Att,Long_Att,~P1/3,Off,

https://www.youtube.com/watch?v=mBbQpaLWcLM&t=45s
https://github.com/lanusStats/futbol-data-visualizacion/blob/main/archivos/streams-videos/introFbref_stream.ipynb


opta radars for EPL
https://www.youtube.com/watch?v=cXtC2EOQj6Q&list=PLSctmZJ-z2wNEsjkL9xMT4T-t-yEdof4N&index=5
https://github.com/mckayjohns/youtube-videos
https://plotly.com/python/radar-chart/

adding gameid to historyDB
miejsce w tabeli fbref.read_schedule() - trzeb sobie samemu wyliczyc tabele

# %%
3 modele to oczywistych1.2/zwyklych1.7/trudnych2.2/

nie styl - JAKOSC - CO DECYDUJE
bramkarz-obrona-pomoc-atak-trener
(PSxG-GA)/SoT; opp_xG; xG; Gls/xG
; SoTA; SCA; ;

bledy popelnione-wykorzystanie bledow
taktyka-trener;elastycznosc-czy zawsze ten sam styl,
# %winsagginst theodds, xG mniejsze przeciwko niemu

taktyka = Dist(shot) C1/3 CPA
offence=Touches[Def3rd Mid3rd Att3rd]
intensity=Touches	
wide=Sw Crs Take-Ons[Att] oppTI xA/PPA
speed=PrgP/Poss poss/prgdist
stalefragmenty =  Dead,FK,TI,CK
press=SCA_Def,Tackles[Def3rd Mid3rd Att3rd], oppRec, Fls AWon P1/3 oppCmp% Recov
contra=sot*(Def3rd/Tackles)
error=ChallengesLost TklW/TklAtt Err Mis Dis CrdY OG Alost
succ= Int TklW ChaTkl Take-Ons[Att]

skalowanie posiadaniem

STYLE
dobrze gra przeciwko defensywnym/ parametry pow sredniej
wylacza z gry gwiazde
press/nopress

jezeli chcemy np PRESS to 
dajemy wszystkie podejzane staty ORAZ oczekiwany wynik np understatPPDA 
i na tym stawiamy model liniowy zeby wiedziec jakie wspolczynniki i ktre zmienne

# %%
ODDs to beat
1,05 - 95
1,11 - 90
1,18 - 85
1,25 - 80

1,33 - 75
1,43 - 70
1,54 - 65
1,67 - 60

1,82 - 55
2,00 - 50
2,22 - 45
2,50 - 40

2,86 - 35
3,33 - 30
4,00 - 25
5,00 - 20
6,67 - 15
10,0 - 10
20,0 - 5

# %%
TODO2
# outliers - moze usunac z trainsetu mecze ktore nie zakonczyly sie tak jak powinny wg kursow historycznych
# usunac mecze latwe bet <1.4

osobny model dla home osobny dla away
# NIEBARDZO offsucc-error zmaiast zwyklego diff, i inne custom ratio np napad/defensywy
# NIE ratio instead of diff
proba inne mierniki jakosci obrony ataku jak np fotmob rating - czy pokrywa sie z moimi metrykami
# wez metryki z poprzedniego sezonu i zobacz jak one sie sprawdzaja, jak zmienily sie te profile yty
zobaczyc ktore mecze zle obstawilo i zastanowic sie jakie czynniki wplynely na taki wynik

# REVERSE
bazujac na kursach > wyliczyc jakie jest prawdopodobienstwo zwyciestwa> jak to sie rozni od intrinsic prob - wiemy ile zmodyfikowali> na podstawie votow> probowac oszacowac ta modyfikacje
model+zarobek+volume_coef
voluem coef mozna tez szacowac po tym jak kurs sie zmienia od wystawienia do poczatku meczu, albo roznica od ceny na gieldzie
zarobek mozna wyliczyc z tego ze sie nie dodaja kursy

# recall vs accuracy co jakby zwiekszyc treshold do >0.6 - zadziej obstawiasz ale mniej przegrywasz
dodac feat forma3 forma5 dniPrzerwy itp
dodac wiecej sezonow na raz

scrape odds
scrape matches
