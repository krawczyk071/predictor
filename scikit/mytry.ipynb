# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
matches = pd.read_csv("matches.csv", index_col=0)
matches
# Out:
#         team        date      time         round  day venue result  gf  ga  \
# 0    Arsenal  2022-08-05  20:00:00   Matchweek 1  Fri  Away      W   2   0
# 1    Arsenal  2022-08-13  15:00:00   Matchweek 2  Sat  Home      W   4   2
# 2    Arsenal  2022-08-20  17:30:00   Matchweek 3  Sat  Away      W   3   0
# 3    Arsenal  2022-08-27  17:30:00   Matchweek 4  Sat  Home      W   2   1
# 4    Arsenal  2022-08-31  19:30:00   Matchweek 5  Wed  Home      W   2   1
# ..       ...         ...       ...           ...  ...   ...    ...  ..  ..
# 755   Wolves  2023-04-29  15:00:00  Matchweek 34  Sat  Away      L   0   6
# 756   Wolves  2023-05-06  15:00:00  Matchweek 35  Sat  Home      W   1   0
# 757   Wolves  2023-05-13  15:00:00  Matchweek 36  Sat  Away      L   0   2
# 758   Wolves  2023-05-20  15:00:00  Matchweek 37  Sat  Home      D   1   1
# 759   Wolves  2023-05-28  16:30:00  Matchweek 38  Sun  Away      L   0   5
#
#            opponent  ...  formation         referee  \
# 0    Crystal Palace  ...      4-3-3  Anthony Taylor
# 1    Leicester City  ...      4-3-3  Darren England
# 2       Bournemouth  ...      4-3-3    Craig Pawson
# 3            Fulham  ...      4-3-3  Jarred Gillett
# 4       Aston Villa  ...      4-3-3    Robert Jones
# ..              ...  ...        ...             ...
# 755        Brighton  ...      4-4-2     David Coote
# 756     Aston Villa  ...      4-4-2  Stuart Attwell
# 757  Manchester Utd  ...      4-4-2     John Brooks
# 758         Everton  ...      4-4-2     David Coote
# 759         Arsenal  ...      4-3-3  Andre Marriner
#
#                                           match_report  notes  sh sot  dist  \
# 0    /en/matches/e62f6e78/Crystal-Palace-Arsenal-Au...    NaN  10   2  14.6
# 1    /en/matches/7483b97f/Arsenal-Leicester-City-Au...    NaN  19   7  13.0
# 2    /en/matches/7f11dd9e/Bournemouth-Arsenal-Augus...    NaN  14   6  14.8
# 3    /en/matches/8b69fd2d/Arsenal-Fulham-August-27-...    NaN  22   8  15.5
# 4    /en/matches/cc235aad/Arsenal-Aston-Villa-Augus...    NaN  22   8  16.3
# ..                                                 ...    ...  ..  ..   ...
# 755  /en/matches/21f920e0/Brighton-and-Hove-Albion-...    NaN  10   2  18.7
# 756  /en/matches/217a7faf/Wolverhampton-Wanderers-A...    NaN   6   2  17.6
# 757  /en/matches/f5d61382/Manchester-United-Wolverh...    NaN   5   0  10.5
# 758  /en/matches/ff2b58c3/Wolverhampton-Wanderers-E...    NaN  13   5  17.9
# 759  /en/matches/71d5bd41/Arsenal-Wolverhampton-Wan...    NaN   6   0  14.7
#
#     fk  pk  pkatt
# 0    1   0      0
# 1    0   0      0
# 2    0   0      0
# 3    1   0      0
# 4    1   0      0
# ..  ..  ..    ...
# 755  0   0      0
# 756  0   0      0
# 757  0   0      0
# 758  1   0      0
# 759  1   0      0
#
# [760 rows x 25 columns]

# %%
# matches=matches.drop('notes',axis=1)
matches=matches.iloc[:,:10]
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
# matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
# matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#         team       date      time         round  day venue result  gf  ga  \
# 0    Arsenal 2022-08-05  20:00:00   Matchweek 1  Fri  Away      W   2   0
# 1    Arsenal 2022-08-13  15:00:00   Matchweek 2  Sat  Home      W   4   2
# 2    Arsenal 2022-08-20  17:30:00   Matchweek 3  Sat  Away      W   3   0
# 3    Arsenal 2022-08-27  17:30:00   Matchweek 4  Sat  Home      W   2   1
# 4    Arsenal 2022-08-31  19:30:00   Matchweek 5  Wed  Home      W   2   1
# ..       ...        ...       ...           ...  ...   ...    ...  ..  ..
# 755   Wolves 2023-04-29  15:00:00  Matchweek 34  Sat  Away      L   0   6
# 756   Wolves 2023-05-06  15:00:00  Matchweek 35  Sat  Home      W   1   0
# 757   Wolves 2023-05-13  15:00:00  Matchweek 36  Sat  Away      L   0   2
# 758   Wolves 2023-05-20  15:00:00  Matchweek 37  Sat  Home      D   1   1
# 759   Wolves 2023-05-28  16:30:00  Matchweek 38  Sun  Away      L   0   5
#
#            opponent  target  venue_code  opp_code
# 0    Crystal Palace       1           0         6
# 1    Leicester City       1           1        10
# 2       Bournemouth       1           0         2
# 3            Fulham       1           1         8
# 4       Aston Villa       1           1         1
# ..              ...     ...         ...       ...
# 755        Brighton       0           0         4
# 756     Aston Villa       1           1         1
# 757  Manchester Utd       0           0        13
# 758         Everton       0           1         7
# 759         Arsenal       0           0         0
#
# [760 rows x 13 columns]

# %%
ranked = pd.read_csv(r"C:\Users\krawc\OneDrive\Documents\code\pythons\predictor\data\ranked_mets_22223.csv", index_col=[0])
ranked
# Out:
#                  goalie   defs   mids   atks  offdeff  intensity  dirspeed  \
# Arsenal            0.55  0.900  0.800  0.950     1.00       0.80      0.10
# Aston Villa        0.60  0.525  0.550  0.750     0.25       0.35      0.55
# Bournemouth        0.35  0.200  0.150  0.575     0.10       0.15      0.50
# Brentford          0.85  0.750  0.650  0.800     0.35       0.10      1.00
# Brighton           0.10  0.700  0.950  0.350     0.80       0.85      0.25
# Chelsea            0.75  0.525  0.500  0.100     0.75       0.90      0.15
# Crystal Palace     0.50  0.850  0.225  0.700     0.40       0.45      0.80
# Everton            0.90  0.100  0.300  0.050     0.50       0.20      0.75
# Fulham             0.95  0.250  0.350  0.850     0.60       0.55      0.30
# Leeds United       0.15  0.050  0.400  0.450     0.70       0.40      0.95
# Leicester City     0.20  0.300  0.600  0.575     0.20       0.65      0.70
# Liverpool          1.00  0.600  0.900  0.650     0.85       0.95      0.45
# Manchester City    0.45  1.000  1.000  1.000     0.95       1.00      0.05
# Manchester Utd     0.65  0.650  0.750  0.150     0.65       0.75      0.40
# Newcastle Utd      0.80  0.950  0.850  0.300     0.90       0.50      0.90
# Nott'ham Forest    0.30  0.150  0.225  0.400     0.05       0.05      0.85
# Southampton        0.05  0.350  0.100  0.500     0.45       0.30      0.60
# Tottenham          0.25  0.800  0.700  0.900     0.30       0.70      0.20
# West Ham           0.70  0.450  0.450  0.250     0.55       0.25      0.65
# Wolves             0.40  0.400  0.050  0.200     0.15       0.60      0.35
#
#                  deads  press  contra  buildup  progress  carr  wings  \
# Arsenal           0.10   0.95    0.45     0.85      0.90  0.20   0.15
# Aston Villa       0.70   0.60    0.70     0.60      0.30  0.95   0.30
# Bournemouth       0.90   0.05    0.50     0.30      0.05  0.85   0.90
# Brentford         0.85   0.45    0.75     0.10      0.80  0.05   0.65
# Brighton          0.20   0.90    0.90     0.90      0.70  0.30   0.20
# Chelsea           0.25   0.85    0.40     0.95      0.35  0.65   0.40
# Crystal Palace    0.75   0.35    0.35     0.40      0.55  0.45   0.80
# Everton           0.80   0.25    0.60     0.15      0.20  0.55   0.95
# Fulham            0.60   0.55    0.25     0.20      0.60  0.80   0.60
# Leeds United      0.95   0.80    0.15     0.55      0.95  0.15   0.45
# Leicester City    0.45   0.30    0.65     0.75      0.10  0.35   0.10
# Liverpool         0.15   1.00    0.85     0.70      0.75  0.10   0.35
# Manchester City   0.05   0.70    0.55     1.00      0.15  0.60   0.05
# Manchester Utd    0.30   0.65    1.00     0.80      0.65  0.40   0.25
# Newcastle Utd     0.50   0.75    0.80     0.50      1.00  0.25   0.75
# Nott'ham Forest   1.00   0.15    0.20     0.05      0.25  0.90   0.55
# Southampton       0.65   0.40    0.30     0.45      0.45  1.00   0.85
# Tottenham         0.35   0.20    0.95     0.65      0.40  0.70   0.50
# West Ham          0.55   0.10    0.05     0.25      0.85  0.75   1.00
# Wolves            0.40   0.50    0.10     0.35      0.50  0.50   0.70
#
#                  agresive  deferror  offsucc
# Arsenal              0.70      0.15     0.85
# Aston Villa          0.55      0.95     0.05
# Bournemouth          0.05      0.70     0.15
# Brentford            0.10      0.80     0.70
# Brighton             0.50      0.50     0.75
# Chelsea              0.90      0.45     0.30
# Crystal Palace       1.00      0.60     0.40
# Everton              0.80      0.30     0.10
# Fulham               0.95      0.85     0.60
# Leeds United         0.45      1.00     0.50
# Leicester City       0.20      0.55     0.55
# Liverpool            0.15      0.25     1.00
# Manchester City      0.30      0.05     0.95
# Manchester Utd       0.85      0.10     0.65
# Newcastle Utd        0.60      0.35     0.90
# Nott'ham Forest      0.75      0.20     0.20
# Southampton          0.65      0.75     0.45
# Tottenham            0.40      0.65     0.80
# West Ham             0.35      0.40     0.35
# Wolves               0.25      0.90     0.25

# %%
full=matches.set_index('team').join(ranked).reset_index(drop=False,names='team')

# %%
full=full.set_index('opponent').join(ranked,rsuffix='_opo').reset_index(drop=False,names='opponent')

# %%
from_ranked=list(full.columns[11:])

# %%
from sklearn.model_selection import train_test_split
predictors = ["venue_code", "opp_code", "hour", "day_code"]
X_train, X_test, y_train, y_test = train_test_split(full[from_ranked], full['target'], test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(X_test)

# %%
error = accuracy_score(y_test, preds)
error
# Out:
# 0.6622807017543859
