# %%
# preditor
# https://github.com/dataquestio/project-walkthroughs/tree/master/football_matches
# https://www.youtube.com/watch?v=0irmDBWLrco&list=PLSctmZJ-z2wNEsjkL9xMT4T-t-yEdof4N&index=9

# %%
import pandas as pd
matches = pd.read_csv("matches.csv", index_col=0)
matches
# Out:
#         team        date      time         round  day venue result  gf  ga  \
# 0    Arsenal  2022-08-05  20:00:00   Matchweek 1  Fri  Away      W   2   0
# 1    Arsenal  2022-08-13  15:00:00   Matchweek 2  Sat  Home      W   4   2
# 2    Arsenal  2022-08-20  17:30:00   Matchweek 3  Sat  Away      W   3   0
# 3    Arsenal  2022-08-27  17:30:00   Matchweek 4  Sat  Home      W   2   1
# 4    Arsenal  2022-08-31  19:30:00   Matchweek 5  Wed  Home      W   2   1
# ..       ...         ...       ...           ...  ...   ...    ...  ..  ..
# 755   Wolves  2023-04-29  15:00:00  Matchweek 34  Sat  Away      L   0   6
# 756   Wolves  2023-05-06  15:00:00  Matchweek 35  Sat  Home      W   1   0
# 757   Wolves  2023-05-13  15:00:00  Matchweek 36  Sat  Away      L   0   2
# 758   Wolves  2023-05-20  15:00:00  Matchweek 37  Sat  Home      D   1   1
# 759   Wolves  2023-05-28  16:30:00  Matchweek 38  Sun  Away      L   0   5
#
#            opponent  ...  formation         referee  \
# 0    Crystal Palace  ...      4-3-3  Anthony Taylor
# 1    Leicester City  ...      4-3-3  Darren England
# 2       Bournemouth  ...      4-3-3    Craig Pawson
# 3            Fulham  ...      4-3-3  Jarred Gillett
# 4       Aston Villa  ...      4-3-3    Robert Jones
# ..              ...  ...        ...             ...
# 755        Brighton  ...      4-4-2     David Coote
# 756     Aston Villa  ...      4-4-2  Stuart Attwell
# 757  Manchester Utd  ...      4-4-2     John Brooks
# 758         Everton  ...      4-4-2     David Coote
# 759         Arsenal  ...      4-3-3  Andre Marriner
#
#                                           match_report  notes  sh sot  dist  \
# 0    /en/matches/e62f6e78/Crystal-Palace-Arsenal-Au...    NaN  10   2  14.6
# 1    /en/matches/7483b97f/Arsenal-Leicester-City-Au...    NaN  19   7  13.0
# 2    /en/matches/7f11dd9e/Bournemouth-Arsenal-Augus...    NaN  14   6  14.8
# 3    /en/matches/8b69fd2d/Arsenal-Fulham-August-27-...    NaN  22   8  15.5
# 4    /en/matches/cc235aad/Arsenal-Aston-Villa-Augus...    NaN  22   8  16.3
# ..                                                 ...    ...  ..  ..   ...
# 755  /en/matches/21f920e0/Brighton-and-Hove-Albion-...    NaN  10   2  18.7
# 756  /en/matches/217a7faf/Wolverhampton-Wanderers-A...    NaN   6   2  17.6
# 757  /en/matches/f5d61382/Manchester-United-Wolverh...    NaN   5   0  10.5
# 758  /en/matches/ff2b58c3/Wolverhampton-Wanderers-E...    NaN  13   5  17.9
# 759  /en/matches/71d5bd41/Arsenal-Wolverhampton-Wan...    NaN   6   0  14.7
#
#     fk  pk  pkatt
# 0    1   0      0
# 1    0   0      0
# 2    0   0      0
# 3    1   0      0
# 4    1   0      0
# ..  ..  ..    ...
# 755  0   0      0
# 756  0   0      0
# 757  0   0      0
# 758  1   0      0
# 759  1   0      0
#
# [760 rows x 25 columns]

# %%
matches["team"].value_counts()
# Out:
# team
# Arsenal            38
# Aston Villa        38
# West Ham           38
# Tottenham          38
# Southampton        38
# Nott'ham Forest    38
# Newcastle Utd      38
# Manchester Utd     38
# Manchester City    38
# Liverpool          38
# Leicester City     38
# Leeds United       38
# Fulham             38
# Everton            38
# Crystal Palace     38
# Chelsea            38
# Brighton           38
# Brentford          38
# Bournemouth        38
# Wolves             38
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# team             object
# date             object
# time             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss              int64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match_report     object
# notes           float64
# sh                int64
# sot               int64
# dist            float64
# fk                int64
# pk                int64
# pkatt             int64
# dtype: object

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#         team       date      time         round  day venue result  gf  ga  \
# 0    Arsenal 2022-08-05  20:00:00   Matchweek 1  Fri  Away      W   2   0
# 1    Arsenal 2022-08-13  15:00:00   Matchweek 2  Sat  Home      W   4   2
# 2    Arsenal 2022-08-20  17:30:00   Matchweek 3  Sat  Away      W   3   0
# 3    Arsenal 2022-08-27  17:30:00   Matchweek 4  Sat  Home      W   2   1
# 4    Arsenal 2022-08-31  19:30:00   Matchweek 5  Wed  Home      W   2   1
# ..       ...        ...       ...           ...  ...   ...    ...  ..  ..
# 755   Wolves 2023-04-29  15:00:00  Matchweek 34  Sat  Away      L   0   6
# 756   Wolves 2023-05-06  15:00:00  Matchweek 35  Sat  Home      W   1   0
# 757   Wolves 2023-05-13  15:00:00  Matchweek 36  Sat  Away      L   0   2
# 758   Wolves 2023-05-20  15:00:00  Matchweek 37  Sat  Home      D   1   1
# 759   Wolves 2023-05-28  16:30:00  Matchweek 38  Sun  Away      L   0   5
#
#            opponent  ...  sot  dist  fk  pk pkatt target venue_code opp_code  \
# 0    Crystal Palace  ...    2  14.6   1   0     0      1          0        6
# 1    Leicester City  ...    7  13.0   0   0     0      1          1       10
# 2       Bournemouth  ...    6  14.8   0   0     0      1          0        2
# 3            Fulham  ...    8  15.5   1   0     0      1          1        8
# 4       Aston Villa  ...    8  16.3   1   0     0      1          1        1
# ..              ...  ...  ...   ...  ..  ..   ...    ...        ...      ...
# 755        Brighton  ...    2  18.7   0   0     0      0          0        4
# 756     Aston Villa  ...    2  17.6   0   0     0      1          1        1
# 757  Manchester Utd  ...    0  10.5   0   0     0      0          0       13
# 758         Everton  ...    5  17.9   1   0     0      0          1        7
# 759         Arsenal  ...    0  14.7   1   0     0      0          0        0
#
#      hour  day_code
# 0      20         4
# 1      15         5
# 2      17         5
# 3      17         5
# 4      19         2
# ..    ...       ...
# 755    15         5
# 756    15         5
# 757    15         5
# 758    15         5
# 759    16         6
#
# [760 rows x 29 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-04-01']
test = matches[matches["date"] > '2023-04-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.5922330097087378

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1
# actual
# 0          96  27
# 1          57  26

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0
ga         opponent  ...  hour  day_code  gf_rolling  ga_rolling  \
# 459   2   Crystal Palace  ...    15         5    3.000000    1.000000
# 460   0  Nott'ham Forest  ...    19         2    3.666667    1.666667
# 461   1      Aston Villa  ...    17         5    4.333333    1.666667
# 462   0           Wolves  ...    12         5    3.666667    1.000000
# 463   3   Manchester Utd  ...    14         6    3.333333    0.333333
# 464   0      Southampton  ...    15         5    3.333333    1.333333
# 465   1        Liverpool  ...    16         6    4.333333    1.000000
# 466   1         Brighton  ...    15         5    3.333333    1.333333
# 467   0   Leicester City  ...    12         5    2.333333    0.666667
# 468   1           Fulham  ...    15         5    1.333333    0.666667
# 469   2        Brentford  ...    12         5    2.000000    0.666667
# 470   1     Leeds United  ...    20         2    1.333333    1.000000
# 471   1          Everton  ...    15         5    2.000000    1.333333
# 472   0          Chelsea  ...    20         3    1.666667    1.333333
# 473   2   Manchester Utd  ...    12         5    1.666667    0.666667
# 474   2        Tottenham  ...    20         3    1.000000    1.000000
# 475   0           Wolves  ...    14         6    2.000000    1.333333
# 476   1        Tottenham  ...    16         6    2.666667    1.333333
# 477   1      Aston Villa  ...    16         6    2.333333    1.000000
# 478   1          Arsenal  ...    19         2    2.000000    0.666667
# 479   1  Nott'ham Forest  ...    15         5    2.000000    1.000000
# 480   1      Bournemouth  ...    17         5    2.333333    1.000000
# 481   0    Newcastle Utd  ...    12         5    2.666667    1.000000
# 482   0   Crystal Palace  ...    17         5    2.333333    0.666667
# 483   1        Liverpool  ...    12         5    2.333333    0.333333
# 484   1      Southampton  ...    17         5    2.333333    0.333333
# 485   1   Leicester City  ...    17         5    3.000000    0.666667
# 486   1          Arsenal  ...    20         2    3.666667    1.000000
# 487   1           Fulham  ...    14         6    3.666667    1.000000
# 488   0         West Ham  ...    20         2    3.000000    1.000000
# 489   1     Leeds United  ...    15         5    3.000000    0.666667
# 490   0          Everton  ...    14         6    2.333333    0.666667
# 491   0          Chelsea  ...    16         6    2.666667    0.333333
# 492   1         Brighton  ...    20         2    2.000000    0.333333
# 493   1        Brentford  ...    16         6    1.666667    0.333333
#
#     sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 459  17.666667    6.000000    17.466667   0.666667    0.333333       0.333333
# 460  19.333333    7.333333    15.933333   0.333333    0.000000       0.000000
# 461  18.666667    8.000000    15.033333   0.333333    0.000000       0.000000
# 462  16.000000    6.000000    15.233333   0.333333    0.000000       0.000000
# 463  15.333333    6.666667    17.000000   0.333333    0.000000       0.000000
# 464  17.000000    6.666667    16.800000   0.666667    0.000000       0.000000
# 465  19.666667    8.000000    15.833333   0.333333    0.000000       0.000000
# 466  19.666667    7.666667    15.500000   0.333333    0.000000       0.000000
# 467  15.333333    5.666667    15.766667   0.000000    0.333333       0.333333
# 468  13.333333    4.666667    18.066667   0.333333    0.333333       0.333333
# 469  13.000000    4.000000    17.966667   0.666667    0.666667       0.666667
# 470  19.666667    5.000000    19.933333   0.666667    0.333333       0.333333
h_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  \
# team
# Arsenal 3    14.333333    5.000000    14.133333   0.333333    0.000000
#         4    18.333333    7.000000    14.433333   0.333333    0.000000
#         5    19.333333    7.333333    15.533333   0.666667    0.000000
#         6    20.000000    6.333333    16.800000   1.000000    0.000000
#         7    17.000000    6.000000    17.700000   0.666667    0.000000
# ...                ...         ...          ...        ...         ...
# Wolves  755  11.666667    4.666667    18.700000   0.666667    0.333333
#         756  11.333333    2.333333    18.800000   0.666667    0.333333
#         757   8.000000    2.000000    17.766667   0.000000    0.333333
#         758   7.000000    1.333333    15.600000   0.000000    0.000000
#         759   8.000000    2.333333    15.333333   0.333333    0.000000
#
#              pkatt_rolling
# team
# Arsenal 3         0.000000
#         4         0.000000
#         5         0.000000
#         6         0.000000
#         7         0.000000
# ...                    ...
# Wolves  755       0.333333
#         756       0.333333
#         757       0.333333
#         758       0.000000
#         759       0.000000
#
# [700 rows x 37 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#         team       date      time         round  day venue result  gf  ga  \
# 3    Arsenal 2022-08-27  17:30:00   Matchweek 4  Sat  Home      W   2   1
# 4    Arsenal 2022-08-31  19:30:00   Matchweek 5  Wed  Home      W   2   1
# 5    Arsenal 2022-09-04  16:30:00   Matchweek 6  Sun  Away      L   1   3
# 6    Arsenal 2022-09-18  12:00:00   Matchweek 8  Sun  Away      W   3   0
# 7    Arsenal 2022-10-01  12:30:00   Matchweek 9  Sat  Home      W   3   1
# ..       ...        ...       ...           ...  ...   ...    ...  ..  ..
# 755   Wolves 2023-04-29  15:00:00  Matchweek 34  Sat  Away      L   0   6
# 756   Wolves 2023-05-06  15:00:00  Matchweek 35  Sat  Home      W   1   0
# 757   Wolves 2023-05-13  15:00:00  Matchweek 36  Sat  Away      L   0   2
# 758   Wolves 2023-05-20  15:00:00  Matchweek 37  Sat  Home      D   1   1
# 759   Wolves 2023-05-28  16:30:00  Matchweek 38  Sun  Away      L   0   5
#
#            opponent  ...  hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# 3            Fulham  ...    17         5    3.000000    0.666667  14.333333
# 4       Aston Villa  ...    19         2    3.000000    1.000000  18.333333
# 5    Manchester Utd  ...    16         6    2.333333    0.666667  19.333333
# 6         Brentford  ...    12         6    1.666667    1.666667  20.000000
# 7         Tottenham  ...    12         5    2.000000    1.333333  17.000000
# ..              ...  ...   ...       ...         ...         ...        ...
# 755        Brighton  ...    15         5    1.666667    0.666667  11.666667
# 756     Aston Villa  ...    15         5    1.000000    2.666667  11.333333
# 757  Manchester Utd  ...    15         5    1.000000    2.000000   8.000000
# 758         Everton  ...    15         5    0.333333    2.666667   7.000000
# 759         Arsenal  ...    16         6    0.666667    1.000000   8.000000
#
#     sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 3      5.000000    14.133333   0.333333    0.000000       0.000000
# 4      7.000000    14.433333   0.333333    0.000000       0.000000
# 5      7.333333    15.533333   0.666667    0.000000       0.000000
# 6      6.333333    16.800000   1.000000    0.000000       0.000000
# 7      6.000000    17.700000   0.666667    0.000000       0.000000
# ..          ...          ...        ...         ...            ...
# 755    4.666667    18.700000   0.666667    0.333333       0.333333
# 756    2.333333    18.800000   0.666667    0.333333       0.333333
# 757    2.000000    17.766667   0.000000    0.333333       0.333333
# 758    1.333333    15.600000   0.000000    0.000000       0.000000
# 759    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [700 rows x 37 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-04-01']
    test = data[data["date"] > '2023-04-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.6153846153846154

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.head(10)
# Out:
#     actual  predicted       date         team         opponent result
# 26       0          0 2023-04-09      Arsenal        Liverpool      D
# 27       0          1 2023-04-16      Arsenal         West Ham      D
# 28       0          1 2023-04-21      Arsenal      Southampton      D
# 29       0          0 2023-04-26      Arsenal  Manchester City      L
# 30       1          0 2023-05-02      Arsenal          Chelsea      W
# 31       1          0 2023-05-07      Arsenal    Newcastle Utd      W
# 32       0          0 2023-05-14      Arsenal         Brighton      L
# 33       0          0 2023-05-20      Arsenal  Nott'ham Forest      L
# 34       1          1 2023-05-28      Arsenal           Wolves      W
# 60       1          1 2023-04-04  Aston Villa   Leicester City      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date   team_x       opponent_x result_x  \
# 0           0            0 2023-04-09  Arsenal        Liverpool        D
# 1           0            1 2023-04-16  Arsenal         West Ham        D
# 2           0            1 2023-04-21  Arsenal      Southampton        D
# 3           0            0 2023-04-26  Arsenal  Manchester City        L
# 4           1            0 2023-05-02  Arsenal          Chelsea        W
# ..        ...          ...        ...      ...              ...      ...
# 201         0            0 2023-04-29   Wolves         Brighton        L
# 202         1            0 2023-05-06   Wolves      Aston Villa        W
# 203         0            0 2023-05-13   Wolves   Manchester Utd        L
# 204         0            0 2023-05-20   Wolves          Everton        D
# 205         0            0 2023-05-28   Wolves          Arsenal        L
#
#     new_team_x  actual_y  predicted_y           team_y opponent_y result_y  \
# 0      Arsenal         0            0        Liverpool    Arsenal        D
# 1      Arsenal         0            0         West Ham    Arsenal        D
# 2      Arsenal         0            0      Southampton    Arsenal        D
# 3      Arsenal         1            1  Manchester City    Arsenal        W
# 4      Arsenal         0            0          Chelsea    Arsenal        L
# ..         ...       ...          ...              ...        ...      ...
# 201     Wolves         1            1         Brighton     Wolves        W
# 202     Wolves         0            0      Aston Villa     Wolves        L
# 203     Wolves         1            1   Manchester Utd     Wolves        W
# 204     Wolves         0            1          Everton     Wolves        D
# 205     Wolves         1            1          Arsenal     Wolves        W
#
#           new_team_y
# 0          Liverpool
# 1           West Ham
# 2        Southampton
# 3    Manchester City
# 4            Chelsea
# ..               ...
# 201         Brighton
# 202      Aston Villa
# 203   Manchester Utd
# 204          Everton
# 205          Arsenal
#
# [206 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    38
# 0    19
# Name: count, dtype: int64
