# %%
import pandas as pd
teams = pd.read_csv("teams.csv", index_col=0)
teams
# Out:
#                  players_used  MP  Starts   Min  90s  GA  GA90  SoTA  Saves  \
# team
# Arsenal                     1  38      38  3420   38  43  1.13   136     94
# Aston Villa                 2  38      38  3420   38  46  1.21   151    108
# Bournemouth                 2  38      38  3420   38  71  1.87   204    136
# Brentford                   1  38      38  3420   38  46  1.21   197    154
# Brighton                    2  38      38  3420   38  53  1.39   131     82
# Chelsea                     2  38      38  3420   38  47  1.24   159    115
# Crystal Palace              3  38      38  3420   38  49  1.29   160    114
# Everton                     2  38      38  3420   38  57  1.50   185    127
# Fulham                      2  38      38  3420   38  53  1.39   196    144
# Leeds United                2  38      38  3420   38  78  2.05   185    108
# Leicester City              2  38      38  3420   38  68  1.79   178    113
# Liverpool                   2  38      38  3420   38  47  1.24   157    111
# Manchester City             2  38      38  3420   38  33  0.87    92     60
# Manchester Utd              1  38      38  3420   38  43  1.13   142     99
# Newcastle Utd               2  38      38  3418   38  33  0.87   127     94
# Nott'ham Forest             3  38      38  3420   38  68  1.79   182    112
# Southampton                 2  38      38  3420   38  73  1.92   150     81
# Tottenham                   2  38      38  3420   38  63  1.66   172    109
# West Ham                    2  38      38  3420   38  55  1.45   170    115
# Wolves                      2  38      38  3420   38  58  1.53   174    115
#
#                  Save%  ...  Fls  Fld  TklW  PKwon  PKcon  OG  Recov  Won  \
# team                    ...
# Arsenal           70.6  ...  373  435   343      3      5   1   1984  486
# Aston Villa       72.8  ...  417  498   338      4      6   4   1847  442
# Bournemouth       68.1  ...  391  365   371      0      7   3   1942  521
# Brentford         77.7  ...  354  399   337      7      2   3   1959  665
# Brighton          64.1  ...  427  407   340      4      8   6   2013  444
# Chelsea           71.1  ...  397  462   445      3      1   3   2024  493
# Crystal Palace    71.9  ...  446  479   421      2      4   3   2093  496
# Everton           71.9  ...  396  382   424      3      6   0   2049  582
# Fulham            76.5  ...  411  405   349      8      8   2   1979  511
# Leeds United      60.5  ...  467  405   480      2      6   1   2206  586
# Leicester City    64.0  ...  410  397   412      5      5   5   2013  512
# Liverpool         71.3  ...  405  321   370      3      4   2   2211  482
# Manchester City   67.4  ...  347  384   272      9      3   1   1866  438
# Manchester Utd    71.1  ...  424  297   400      2      3   1   2190  465
# Newcastle Utd     75.6  ...  406  399   360      2      5   2   2065  553
# Nott'ham Forest   65.9  ...  445  390   387      3      9   0   1902  560
# Southampton       52.7  ...  430  378   426      3      3   5   2130  551
# Tottenham         65.1  ...  424  353   353      5      4   1   1984  549
# West Ham          70.0  ...  362  316   335      6      6   1   2023  620
# Wolves            67.8  ...  463  389   370      1      4   1   2052  465
#
#                  Lost  Won%
# team
# Arsenal           559  46.5
# Aston Villa       465  48.7
# Bournemouth       539  49.2
# Brentford         618  51.8
# Brighton          387  53.4
# Chelsea           453  52.1
# Crystal Palace    578  46.2
# Everton           613  48.7
# Fulham            550  48.2
# Leeds United      607  49.1
# Leicester City    558  47.9
# Liverpool         455  51.4
# Manchester City   364  54.6
# Manchester Utd    434  51.7
# Newcastle Utd     427  56.4
# Nott'ham Forest   600  48.3
# Southampton       611  47.4
# Tottenham         474  53.7
# West Ham          587  51.4
# Wolves            542  46.2
#
# [20 rows x 147 columns]

# %%
# https://github.com/lanusStats/futbol-data-visualizacion/blob/main/archivos/streams-videos/introFbref_stream.ipynb

# %%
import pandas as pd
from matplotlib.offsetbox import (OffsetImage,AnnotationBbox)
import matplotlib.pyplot as plt
from mplsoccer import FontManager, add_image
from PIL import Image



URL3 = 'https://github.com/VanillaandCream/Catamaran-Tamil/blob/master/Fonts/Catamaran-Medium.ttf?raw=true'
catamaran2 = FontManager(URL3)
URL = 'https://github.com/google/fonts/blob/main/ofl/fjallaone/FjallaOne-Regular.ttf?raw=true'
robotto_regular = FontManager(URL)
URL2 = 'https://github.com/VanillaandCream/Catamaran-Tamil/blob/master/Fonts/Catamaran-ExtraBold.ttf?raw=true'
catamaran = FontManager(URL2)
URL4 = 'https://github.com/google/fonts/blob/main/ofl/bungeeinline/BungeeInline-Regular.ttf?raw=true'
titulo = FontManager(URL4)

# %%
df_plot =teams[['MP', 'Saves', 'Save%']].reset_index()
df_plot.columns=['Squad', 'MP', 'Saves', 'Save%']
# df_plot=df_plot.iloc[[0]]

# %%
df_plot['Saves / partido'] = df_plot['Saves'] / df_plot['MP']

# %%
#Seteo los parametros del scatter
x, promx = df_plot['Save%'], df_plot['Save%'].mean() 
y, promy = df_plot['Saves / partido'], df_plot['Saves / partido'].mean()

#Consideraciones generales
facecolor = '#292323'
color_plot = 'white'

#Figura, axis y el scatter
fig, ax = plt.subplots(figsize =(20, 12))
ax.scatter(x, y)

#Detalles esteticos
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(color_plot)
ax.spines['left'].set_color(color_plot)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)
ax.yaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)
ax.xaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)

fig.patch.set_facecolor(facecolor)
ax.set_facecolor(facecolor)
ax.grid(visible=True, color =color_plot,linestyle ='-', linewidth = 0,alpha = 0.5)
ax.grid(which='minor', color =color_plot,linestyle ='-', linewidth = 1.5, alpha=1)

#Lineas de Promedio
ax.axvline(promx, color=color_plot)
ax.axhline(promy, color=color_plot)

#Nombres de labels y titulo
nombreAtr1 = 'Goles concedidos'
nombreAtr2 = 'Tiros al arco concedidos'

ax.set_xlabel(nombreAtr1, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_ylabel(nombreAtr2, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_title(nombreAtr1+' Vs '+nombreAtr2+''+' - Torneo Binance 2023', fontproperties=titulo.prop,
                     loc ='left', color=color_plot,fontsize = 25,fontweight="bold", pad=20)
# Out:
# Text(0.0, 1.0, 'Goles concedidos Vs Tiros al arco concedidos - Torneo Binance 2023')

# %%
import os
path = os.getcwd()
files = os.listdir('ejemplo')
files
# Out:
# ['Arsenal.png']

# %%
def path_logo():
    return './ejemplo/'
    # return {path a la imagen}}
    
#Seteo los parametros del scatter
x, promx = df_plot['Save%'], df_plot['Save%'].mean() 
y, promy = df_plot['Saves / partido'], df_plot['Saves / partido'].mean()

#Consideraciones generales
facecolor = '#292323'
color_plot = 'white'

#Figura, axis y el scatter
fig, ax = plt.subplots(figsize =(20, 12))
ax.scatter(x, y)

#Detalles esteticos
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(color_plot)
ax.spines['left'].set_color(color_plot)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)
ax.yaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)
ax.xaxis.set_tick_params(pad = 12,colors=color_plot,labelsize=12)

fig.patch.set_facecolor(facecolor)
ax.set_facecolor(facecolor)
ax.grid(visible=True, color =color_plot,linestyle ='-', linewidth = 0,alpha = 0.5)
ax.grid(which='minor', color =color_plot,linestyle ='-', linewidth = 1.5, alpha=1)

#Lineas de Promedio
ax.axvline(promx, color=color_plot)
ax.axhline(promy, color=color_plot)

#Nombres de labels y titulo
nombreAtr1 = '% de tiros atajados'
nombreAtr2 = 'Atajadas por partido'

ax.set_xlabel(nombreAtr1, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_ylabel(nombreAtr2, fontproperties=catamaran2.prop,fontsize=18,color=color_plot)
ax.set_title(nombreAtr1+' Vs '+nombreAtr2+''+' - Torneo Binance 2023', fontproperties=titulo.prop,
                     loc ='left', color=color_plot,fontsize = 25,fontweight="bold", pad=20)

#Escudos
def getImage(path, zoom=0.17):
    return OffsetImage(plt.imread(path), zoom=zoom)

for x0, y0, file in zip(x, y,files):
    path = path.lower()
    ab = AnnotationBbox(getImage(f'ejemplo/{file}'), (x0, y0), frameon=False)
    ax.add_artist(ab)


ax_image = add_image(
    Image.open(path_logo()), fig, left=0.07, bottom=0.8774, width=0.053, height=0.053
)

plt.savefig(nombreAtr1+' Vs '+nombreAtr2+''+' - Torneo Binance 2023', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\play_styles\two.ipynb Cell 8 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/predictor/play_styles/two.ipynb#X11sZmlsZQ%3D%3D?line=50'>51</a>     ab = AnnotationBbox(getImage(f'ejemplo/{file}'), (x0, y0), frameon=False)
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/predictor/play_styles/two.ipynb#X11sZmlsZQ%3D%3D?line=51'>52</a>     ax.add_artist(ab)
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/predictor/play_styles/two.ipynb#X11sZmlsZQ%3D%3D?line=54'>55</a> ax_image = add_image(
# ---> <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/predictor/play_styles/two.ipynb#X11sZmlsZQ%3D%3D?line=55'>56</a>     Image.open(path_logo()), fig, left=0.07, bottom=0.8774, width=0.053, height=0.053
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/predictor/play_styles/two.ipynb#X11sZmlsZQ%3D%3D?line=56'>57</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/predictor/play_styles/two.ipynb#X11sZmlsZQ%3D%3D?line=58'>59</a> plt.savefig(nombreAtr1+' Vs '+nombreAtr2+''+' - Torneo Binance 2023', dpi=300, bbox_inches='tight')
#
# File c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\PIL\Image.py:3218, in open(fp, mode, formats)
#    3215     filename = fp
#    3217 if filename:
# -> 3218     fp = builtins.open(filename, "rb")
#    3219     exclusive_fp = True
#    3221 try:
#
# PermissionError: [Errno 13] Permission denied: './ejemplo/'
