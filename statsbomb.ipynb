# %%
https://github.com/statsbomb/open-data
https://github.com/statsbomb/statsbombpy

# %%
import pandas as pd
import requests

url='https://github.com/statsbomb/open-data/blob/master/data/competitions.json'

r = requests.get(url)

j = r.json()

df = pd.DataFrame.from_dict(j)

# %%
from statsbombpy import sb

# %%
sb.competitions(fmt="dict")
sb.competitions()
# Out:
# c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 62              55         43         Europe           UEFA Euro
# 63              35         75         Europe  UEFA Europa League
# 64              53        106         Europe   UEFA Women's Euro
# 65              72        107  International   Women's World Cup
# 66              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 2                male              False                      False
# 3                male              False                      False
# 4                male              False                      False
# ..                ...                ...                        ...
# 62               male              False                       True
# 63               male              False                      False
# 64             female              False                       True
# 65             female              False                       True
# 66             female              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 0    2015/2016  2023-08-17T23:51:11.837478                        None
# 1    2018/2019  2023-03-07T12:20:48.118250     2021-06-13T16:17:31.694
# 2    2017/2018  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# 3    2016/2017  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# 4    2015/2016  2021-08-27T11:26:39.802832     2021-06-13T16:17:31.694
# ..         ...                         ...                         ...
# 62        2020  2023-02-24T21:26:47.128979  2023-04-27T22:38:34.970148
# 63   1988/1989  2023-06-18T19:28:39.443883     2021-06-13T16:17:31.694
# 64        2022  2023-07-17T21:19:03.032991  2023-07-17T21:21:56.497106
# 65        2023  2023-09-01T12:34:19.705316  2023-09-01T12:35:45.762196
# 66        2019  2023-07-27T10:33:48.273734     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 0                         None  2023-08-17T23:51:11.837478
# 1                         None  2023-03-07T12:20:48.118250
# 2                         None  2021-01-23T21:55:30.425330
# 3                         None            2020-07-29T05:00
# 4                         None            2020-07-29T05:00
# ..                         ...                         ...
# 62  2023-04-27T22:38:34.970148  2023-02-24T21:26:47.128979
# 63                        None  2023-06-18T19:28:39.443883
# 64  2023-07-17T21:21:56.497106  2023-07-17T21:19:03.032991
# 65  2023-09-01T12:35:45.762196  2023-09-01T12:34:19.705316
# 66                        None  2023-07-27T10:33:48.273734
#
# [67 rows x 12 columns]

# %%
sb.matches(competition_id=9, season_id=42)
sb.lineups(match_id=303299)["Eintracht Frankfurt"]
events = sb.events(match_id=303299)
sb.events(match_id=303299, split=True, flatten_attrs=False)["dribbles"]

# %%
# Out:
# {('Germany', '1. Bundesliga', '2015/2016', 'male'): {'competition_id': 9,
#   'season_id': 27,
#   'country_name': 'Germany',
#   'competition_name': '1. Bundesliga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2015/2016',
#   'match_updated': '2023-08-17T23:51:11.837478',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-08-17T23:51:11.837478'},
#  ('Europe', 'Champions League', '2018/2019', 'male'): {'competition_id': 16,
#   'season_id': 4,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2018/2019',
#   'match_updated': '2023-03-07T12:20:48.118250',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-03-07T12:20:48.118250'},
#  ('Europe', 'Champions League', '2017/2018', 'male'): {'competition_id': 16,
#   'season_id': 1,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2017/2018',
#   'match_updated': '2021-08-27T11:26:39.802832',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2021-01-23T21:55:30.425330'},
#  ('Europe', 'Champions League', '2016/2017', 'male'): {'competition_id': 16,
#   'season_id': 2,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2016/2017',
#   'match_updated': '2021-08-27T11:26:39.802832',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Europe', 'Champions League', '2015/2016', 'male'): {'competition_id': 16,
#   'season_id': 27,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2015/2016',
#   'match_updated': '2021-08-27T11:26:39.802832',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Europe', 'Champions League', '2014/2015', 'male'): {'competition_id': 16,
#   'season_id': 26,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2014/2015',
#   'match_updated': '2021-08-27T11:26:39.802832',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Europe', 'Champions League', '2013/2014', 'male'): {'competition_id': 16,
#   'season_id': 25,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2013/2014',
#   'match_updated': '2021-08-27T11:26:39.802832',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Europe', 'Champions League', '2012/2013', 'male'): {'competition_id': 16,
#   'season_id': 24,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2012/2013',
#   'match_updated': '2021-08-27T11:26:39.802832',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2021-07-10T13:41:45.751'},
#  ('Europe', 'Champions League', '2011/2012', 'male'): {'competition_id': 16,
#   'season_id': 23,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2011/2012',
#   'match_updated': '2021-08-27T11:26:39.802832',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Europe', 'Champions League', '2010/2011', 'male'): {'competition_id': 16,
#   'season_id': 22,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2010/2011',
#   'match_updated': '2022-01-26T21:07:11.033473',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2022-01-26T21:07:11.033473'},
#  ('Europe', 'Champions League', '2009/2010', 'male'): {'competition_id': 16,
#   'season_id': 21,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2009/2010',
#   'match_updated': '2022-11-15T17:26:10.871011',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2022-11-15T17:26:10.871011'},
#  ('Europe', 'Champions League', '2008/2009', 'male'): {'competition_id': 16,
#   'season_id': 41,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2008/2009',
#   'match_updated': '2021-11-07T14:20:01.699993',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2021-11-07T14:20:01.699993'},
#  ('Europe', 'Champions League', '2006/2007', 'male'): {'competition_id': 16,
#   'season_id': 39,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2006/2007',
#   'match_updated': '2021-03-31T04:18:30.437060',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2021-03-31T04:18:30.437060'},
#  ('Europe', 'Champions League', '2004/2005', 'male'): {'competition_id': 16,
#   'season_id': 37,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2004/2005',
#   'match_updated': '2021-04-01T06:18:57.459032',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2021-04-01T06:18:57.459032'},
#  ('Europe', 'Champions League', '2003/2004', 'male'): {'competition_id': 16,
#   'season_id': 44,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2003/2004',
#   'match_updated': '2022-11-24T21:06:10.454916',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2022-11-24T21:06:10.454916'},
#  ('Europe', 'Champions League', '1999/2000', 'male'): {'competition_id': 16,
#   'season_id': 76,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1999/2000',
#   'match_updated': '2020-07-29T05:00',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Europe', 'Champions League', '1972/1973', 'male'): {'competition_id': 16,
#   'season_id': 277,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1972/1973',
#   'match_updated': '2023-07-06T12:49:07.467625',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-07-06T12:49:07.467625'},
#  ('Europe', 'Champions League', '1971/1972', 'male'): {'competition_id': 16,
#   'season_id': 71,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1971/1972',
#   'match_updated': '2020-07-29T05:00',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Europe', 'Champions League', '1970/1971', 'male'): {'competition_id': 16,
#   'season_id': 276,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1970/1971',
#   'match_updated': '2023-07-06T12:50:01.961048',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-07-06T12:50:01.961048'},
#  ('Spain', 'Copa del Rey', '1983/1984', 'male'): {'competition_id': 87,
#   'season_id': 84,
#   'country_name': 'Spain',
#   'competition_name': 'Copa del Rey',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1983/1984',
#   'match_updated': '2020-07-29T05:00',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Spain', 'Copa del Rey', '1982/1983', 'male'): {'competition_id': 87,
#   'season_id': 268,
#   'country_name': 'Spain',
#   'competition_name': 'Copa del Rey',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1982/1983',
#   'match_updated': '2023-06-11T02:51:59.941964',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-06-11T02:51:59.941964'},
#  ('Spain', 'Copa del Rey', '1977/1978', 'male'): {'competition_id': 87,
#   'season_id': 279,
#   'country_name': 'Spain',
#   'competition_name': 'Copa del Rey',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1977/1978',
#   'match_updated': '2023-06-26T10:36:15.442581',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-06-26T10:36:15.442581'},
#  ('England',
#   "FA Women's Super League",
#   '2020/2021',
#   'female'): {'competition_id': 37, 'season_id': 90, 'country_name': 'England', 'competition_name': "FA Women's Super League", 'competition_gender': 'female', 'competition_youth': False, 'competition_international': False, 'season_name': '2020/2021', 'match_updated': '2023-02-25T14:52:09.326729', 'match_updated_360': '2021-06-13T16:17:31.694', 'match_available_360': None, 'match_available': '2023-02-25T14:52:09.326729'},
#  ('England',
#   "FA Women's Super League",
#   '2019/2020',
#   'female'): {'competition_id': 37, 'season_id': 42, 'country_name': 'England', 'competition_name': "FA Women's Super League", 'competition_gender': 'female', 'competition_youth': False, 'competition_international': False, 'season_name': '2019/2020', 'match_updated': '2023-07-25T01:08:03.214566', 'match_updated_360': '2021-06-13T16:17:31.694', 'match_available_360': None, 'match_available': '2023-07-25T01:08:03.214566'},
#  ('England',
#   "FA Women's Super League",
#   '2018/2019',
#   'female'): {'competition_id': 37, 'season_id': 4, 'country_name': 'England', 'competition_name': "FA Women's Super League", 'competition_gender': 'female', 'competition_youth': False, 'competition_international': False, 'season_name': '2018/2019', 'match_updated': '2023-07-24T19:50:20.881595', 'match_updated_360': '2021-06-13T16:17:31.694', 'match_available_360': None, 'match_available': '2023-07-24T19:50:20.881595'},
#  ('International',
#   'FIFA U20 World Cup',
#   '1979',
#   'male'): {'competition_id': 1470, 'season_id': 274, 'country_name': 'International', 'competition_name': 'FIFA U20 World Cup', 'competition_gender': 'male', 'competition_youth': False, 'competition_international': False, 'season_name': '1979', 'match_updated': '2023-06-28T10:55:11.501179', 'match_updated_360': None, 'match_available_360': None, 'match_available': '2023-06-28T10:55:11.501179'},
#  ('International', 'FIFA World Cup', '2022', 'male'): {'competition_id': 43,
#   'season_id': 106,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '2022',
#   'match_updated': '2023-08-12T16:44:27.619465',
#   'match_updated_360': '2023-08-17T15:55:15.164685',
#   'match_available_360': '2023-08-17T15:55:15.164685',
#   'match_available': '2023-08-12T16:44:27.619465'},
#  ('International', 'FIFA World Cup', '2018', 'male'): {'competition_id': 43,
#   'season_id': 3,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '2018',
#   'match_updated': '2023-07-24T13:09:34.513519',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-24T13:09:34.513519'},
#  ('International', 'FIFA World Cup', '1990', 'male'): {'competition_id': 43,
#   'season_id': 55,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '1990',
#   'match_updated': '2023-06-28T10:58:20.137929',
#   'match_updated_360': '2021-06-12T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-06-28T10:58:20.137929'},
#  ('International', 'FIFA World Cup', '1986', 'male'): {'competition_id': 43,
#   'season_id': 54,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '1986',
#   'match_updated': '2023-06-28T11:20:34.252935',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-06-28T11:20:34.252935'},
#  ('International', 'FIFA World Cup', '1974', 'male'): {'competition_id': 43,
#   'season_id': 51,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '1974',
#   'match_updated': '2023-07-17T23:19:58.853207',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-17T23:19:58.853207'},
#  ('International', 'FIFA World Cup', '1970', 'male'): {'competition_id': 43,
#   'season_id': 272,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '1970',
#   'match_updated': '2023-07-17T23:24:45.579886',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-07-17T23:24:45.579886'},
#  ('International', 'FIFA World Cup', '1962', 'male'): {'competition_id': 43,
#   'season_id': 270,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '1962',
#   'match_updated': '2023-06-26T10:38:00.323984',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-06-26T10:38:00.323984'},
#  ('International', 'FIFA World Cup', '1958', 'male'): {'competition_id': 43,
#   'season_id': 269,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '1958',
#   'match_updated': '2023-06-26T10:33:08.214831',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-06-26T10:33:08.214831'},
#  ('India',
#   'Indian Super league',
#   '2021/2022',
#   'male'): {'competition_id': 1238, 'season_id': 108, 'country_name': 'India', 'competition_name': 'Indian Super league', 'competition_gender': 'male', 'competition_youth': False, 'competition_international': False, 'season_name': '2021/2022', 'match_updated': '2023-03-31T02:14:09.896947', 'match_updated_360': None, 'match_available_360': None, 'match_available': '2023-03-31T02:14:09.896947'},
#  ('Spain', 'La Liga', '2020/2021', 'male'): {'competition_id': 11,
#   'season_id': 90,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2020/2021',
#   'match_updated': '2023-07-26T14:11:01.312143',
#   'match_updated_360': '2023-07-26T14:15:15.217027',
#   'match_available_360': '2023-07-26T14:15:15.217027',
#   'match_available': '2023-07-26T14:11:01.312143'},
#  ('Spain', 'La Liga', '2019/2020', 'male'): {'competition_id': 11,
#   'season_id': 42,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2019/2020',
#   'match_updated': '2023-07-25T00:16:32.999467',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-25T00:16:32.999467'},
#  ('Spain', 'La Liga', '2018/2019', 'male'): {'competition_id': 11,
#   'season_id': 4,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2018/2019',
#   'match_updated': '2023-08-03T02:24:43.761907',
#   'match_updated_360': '2021-07-09T14:53:22.103024',
#   'match_available_360': None,
#   'match_available': '2023-08-03T02:24:43.761907'},
#  ('Spain', 'La Liga', '2017/2018', 'male'): {'competition_id': 11,
#   'season_id': 1,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2017/2018',
#   'match_updated': '2023-07-24T13:03:48.574627',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-24T13:03:48.574627'},
#  ('Spain', 'La Liga', '2016/2017', 'male'): {'competition_id': 11,
#   'season_id': 2,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2016/2017',
#   'match_updated': '2023-07-25T00:14:55.260536',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-25T00:14:55.260536'},
#  ('Spain', 'La Liga', '2015/2016', 'male'): {'competition_id': 11,
#   'season_id': 27,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2015/2016',
#   'match_updated': '2023-07-24T21:52:42.890908',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-24T21:52:42.890908'},
#  ('Spain', 'La Liga', '2014/2015', 'male'): {'competition_id': 11,
#   'season_id': 26,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2014/2015',
#   'match_updated': '2023-07-24T21:50:15.215072',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-24T21:50:15.215072'},
#  ('Spain', 'La Liga', '2013/2014', 'male'): {'competition_id': 11,
#   'season_id': 25,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2013/2014',
#   'match_updated': '2022-07-23T12:18:49.547396',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2022-07-23T12:18:49.547396'},
#  ('Spain', 'La Liga', '2012/2013', 'male'): {'competition_id': 11,
#   'season_id': 24,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2012/2013',
#   'match_updated': '2022-09-25T20:52:24.444609',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2022-09-25T20:52:24.444609'},
#  ('Spain', 'La Liga', '2011/2012', 'male'): {'competition_id': 11,
#   'season_id': 23,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2011/2012',
#   'match_updated': '2022-12-01T14:10:17.791769',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2022-12-01T14:10:17.791769'},
#  ('Spain', 'La Liga', '2010/2011', 'male'): {'competition_id': 11,
#   'season_id': 22,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2010/2011',
#   'match_updated': '2023-04-19T10:48:44.079830',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-04-19T10:48:44.079830'},
#  ('Spain', 'La Liga', '2009/2010', 'male'): {'competition_id': 11,
#   'season_id': 21,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2009/2010',
#   'match_updated': '2023-04-19T10:48:01.770383',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-04-19T10:48:01.770383'},
#  ('Spain', 'La Liga', '2008/2009', 'male'): {'competition_id': 11,
#   'season_id': 41,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2008/2009',
#   'match_updated': '2023-04-19T10:46:29.203565',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-04-19T10:46:29.203565'},
#  ('Spain', 'La Liga', '2007/2008', 'male'): {'competition_id': 11,
#   'season_id': 40,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2007/2008',
#   'match_updated': '2023-04-19T10:42:35.284291',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-04-19T10:42:35.284291'},
#  ('Spain', 'La Liga', '2006/2007', 'male'): {'competition_id': 11,
#   'season_id': 39,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2006/2007',
#   'match_updated': '2023-03-26T23:19:39.125951',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-03-26T23:19:39.125951'},
#  ('Spain', 'La Liga', '2005/2006', 'male'): {'competition_id': 11,
#   'season_id': 38,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2005/2006',
#   'match_updated': '2022-07-03T12:34:31.749038',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2022-07-03T12:34:31.749038'},
#  ('Spain', 'La Liga', '2004/2005', 'male'): {'competition_id': 11,
#   'season_id': 37,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2004/2005',
#   'match_updated': '2020-07-29T05:00',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2020-07-29T05:00'},
#  ('Spain', 'La Liga', '1973/1974', 'male'): {'competition_id': 11,
#   'season_id': 278,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1973/1974',
#   'match_updated': '2023-07-06T12:50:48.807820',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-07-06T12:50:48.807820'},
#  ('Argentina', 'Liga Profesional', '1997/1998', 'male'): {'competition_id': 81,
#   'season_id': 48,
#   'country_name': 'Argentina',
#   'competition_name': 'Liga Profesional',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1997/1998',
#   'match_updated': '2023-06-28T11:19:54.593488',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-06-28T11:19:54.593488'},
#  ('Argentina', 'Liga Profesional', '1981', 'male'): {'competition_id': 81,
#   'season_id': 275,
#   'country_name': 'Argentina',
#   'competition_name': 'Liga Profesional',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1981',
#   'match_updated': '2023-06-28T11:31:57.152298',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-06-28T11:31:57.152298'},
#  ('France', 'Ligue 1', '2015/2016', 'male'): {'competition_id': 7,
#   'season_id': 27,
#   'country_name': 'France',
#   'competition_name': 'Ligue 1',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2015/2016',
#   'match_updated': '2023-08-31T19:38:46.331149',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-08-31T19:38:46.331149'},
#  ('North and Central America',
#   'North American League',
#   '1977',
#   'male'): {'competition_id': 116, 'season_id': 68, 'country_name': 'North and Central America', 'competition_name': 'North American League', 'competition_gender': 'male', 'competition_youth': False, 'competition_international': False, 'season_name': '1977', 'match_updated': '2023-07-24T09:06:54.144896', 'match_updated_360': '2021-06-13T16:17:31.694', 'match_available_360': None, 'match_available': '2023-07-24T09:06:54.144896'},
#  ('United States of America', 'NWSL', '2018', 'female'): {'competition_id': 49,
#   'season_id': 3,
#   'country_name': 'United States of America',
#   'competition_name': 'NWSL',
#   'competition_gender': 'female',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2018',
#   'match_updated': '2023-07-24T13:01:22.094587',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-24T13:01:22.094587'},
#  ('England', 'Premier League', '2015/2016', 'male'): {'competition_id': 2,
#   'season_id': 27,
#   'country_name': 'England',
#   'competition_name': 'Premier League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2015/2016',
#   'match_updated': '2023-07-12T13:59:45.191483',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-07-12T13:59:45.191483'},
#  ('England', 'Premier League', '2003/2004', 'male'): {'competition_id': 2,
#   'season_id': 44,
#   'country_name': 'England',
#   'competition_name': 'Premier League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2003/2004',
#   'match_updated': '2023-03-11T10:52:12.579230',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-03-11T10:52:12.579230'},
#  ('Italy', 'Serie A', '2015/2016', 'male'): {'competition_id': 12,
#   'season_id': 27,
#   'country_name': 'Italy',
#   'competition_name': 'Serie A',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '2015/2016',
#   'match_updated': '2023-08-31T16:46:34.290341',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-08-31T16:46:34.290341'},
#  ('Italy', 'Serie A', '1986/1987', 'male'): {'competition_id': 12,
#   'season_id': 86,
#   'country_name': 'Italy',
#   'competition_name': 'Serie A',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1986/1987',
#   'match_updated': '2023-06-18T01:55:53.343752',
#   'match_updated_360': None,
#   'match_available_360': None,
#   'match_available': '2023-06-18T01:55:53.343752'},
#  ('Europe', 'UEFA Euro', '2020', 'male'): {'competition_id': 55,
#   'season_id': 43,
#   'country_name': 'Europe',
#   'competition_name': 'UEFA Euro',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '2020',
#   'match_updated': '2023-02-24T21:26:47.128979',
#   'match_updated_360': '2023-04-27T22:38:34.970148',
#   'match_available_360': '2023-04-27T22:38:34.970148',
#   'match_available': '2023-02-24T21:26:47.128979'},
#  ('Europe', 'UEFA Europa League', '1988/1989', 'male'): {'competition_id': 35,
#   'season_id': 75,
#   'country_name': 'Europe',
#   'competition_name': 'UEFA Europa League',
#   'competition_gender': 'male',
#   'competition_youth': False,
#   'competition_international': False,
#   'season_name': '1988/1989',
#   'match_updated': '2023-06-18T19:28:39.443883',
#   'match_updated_360': '2021-06-13T16:17:31.694',
#   'match_available_360': None,
#   'match_available': '2023-06-18T19:28:39.443883'},
#  ('Europe', "UEFA Women's Euro", '2022', 'female'): {'competition_id': 53,
#   'season_id': 106,
#   'country_name': 'Europe',
#   'competition_name': "UEFA Women's Euro",
#   'competition_gender': 'female',
#   'competition_youth': False,
#   'competition_international': True,
#   'season_name': '2022',
#   'match_updated': '2023-07-17T21:19:03.032991',
#   'match_updated_360': '2023-07-17T21:21:56.497106',
#   'match_available_360': '2023-07-17T21:21:56.497106',
#   'match_available': '2023-07-17T21:19:03.032991'},
#  ('International',
#   "Women's World Cup",
#   '2023',
#   'female'): {'competition_id': 72, 'season_id': 107, 'country_name': 'International', 'competition_name': "Women's World Cup", 'competition_gender': 'female', 'competition_youth': False, 'competition_international': True, 'season_name': '2023', 'match_updated': '2023-09-01T12:34:19.705316', 'match_updated_360': '2023-09-01T12:35:45.762196', 'match_available_360': '2023-09-01T12:35:45.762196', 'match_available': '2023-09-01T12:34:19.705316'},
#  ('International',
#   "Women's World Cup",
#   '2019',
#   'female'): {'competition_id': 72, 'season_id': 30, 'country_name': 'International', 'competition_name': "Women's World Cup", 'competition_gender': 'female', 'competition_youth': False, 'competition_international': True, 'season_name': '2019', 'match_updated': '2023-07-27T10:33:48.273734', 'match_updated_360': '2021-06-13T16:17:31.694', 'match_available_360': None, 'match_available': '2023-07-27T10:33:48.273734'}}
