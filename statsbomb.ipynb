# %%
https://github.com/statsbomb/open-data
https://github.com/statsbomb/statsbombpy

# %%
import pandas as pd
import requests

url='https://github.com/statsbomb/open-data/blob/master/data/competitions.json'

r = requests.get(url)

j = r.json()

df = pd.DataFrame.from_dict(j)

# %%
from statsbombpy import sb

# %%
# competitions>matches>lineups-match
sb.competitions(fmt="dict")
sb.competitions()
# Out:
#     competition_id  season_id   country_name    competition_name  \
# 0                9         27        Germany       1. Bundesliga
# 1               16          4         Europe    Champions League
# 2               16          1         Europe    Champions League
# 3               16          2         Europe    Champions League
# 4               16         27         Europe    Champions League
# ..             ...        ...            ...                 ...
# 62              55         43         Europe           UEFA Euro
# 63              35         75         Europe  UEFA Europa League
# 64              53        106         Europe   UEFA Women's Euro
# 65              72        107  International   Women's World Cup
# 66              72         30  International   Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
sb.matches(competition_id=9, season_id=27).iloc[0]
# Out:
# c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# match_id                                    3890561
# match_date                               2016-05-14
# kick_off                               15:30:00.000
# competition                 Germany - 1. Bundesliga
# season                                    2015/2016
# home_team                                Hoffenheim
# away_team                                Schalke 04
# home_score                                        1
# away_score                                        4
# match_status                              available
# match_status_360                        unscheduled
# last_updated             2023-07-24T07:47:12.510532
# last_updated_360                               None
# match_week                                       34
# ...

# %%
sb.lineups(match_id=3890561)["Hoffenheim"]
# Out:
# c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     player_id                 player_name player_nickname  jersey_number  \
# 0        5460             Andrej Kramarić            None             27
# 1        5537          Fabian Lukas Schär    Fabian Schär              5
# 2        6039              Sebastian Rudy            None              6
# 3        8215               Kevin Volland            None             31
# 4        8387                    Mark Uth            None             19
# 5        8392               Jeremy Toljan            None             15
# 6        8393              Oliver Baumann            None              1
# 7        8403                Nadiem Amiri            None             18
# 8        8404              Eugen Polanski            None              8
# ...

# %%
sb.events(match_id=3890561).iloc[0]
# Out:
# c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ball_receipt_outcome                       NaN
# ball_recovery_recovery_failure             NaN
# block_deflection                           NaN
# carry_end_location                         NaN
# clearance_aerial_won                       NaN
#                                       ...
# team                                Hoffenheim
# team_id                                    175
# timestamp                         00:00:00.000
# type                               Starting XI
# under_pressure                             NaN
# Name: 0, Length: 83, dtype: object

# %%
sb.events(match_id=3890561, split=True, flatten_attrs=False)["dribbles"]
# Out:
# c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#                                       id  index  period     timestamp  minute  \
# 0   6e3eb685-d7bc-41db-901b-3d90e5bc65be    323       1  00:05:58.639       5
# 1   f311d59b-a85a-4807-9ba4-0f43c95c2388    342       1  00:06:13.364       6
# 2   83f3099b-aab8-4060-9b1f-26fe29cadbfc    375       1  00:07:37.559       7
# 3   01d5507d-e555-4e4b-ab39-279f3973998f    389       1  00:07:54.708       7
# 4   39ccc41c-e10f-4bdc-a4d7-fb8d599b7941    507       1  00:10:46.063      10
# 5   b5bfb8ae-18a8-4a61-8064-d59943bc9dfe    622       1  00:13:54.508      13
# 6   26cb7dab-f37f-4db1-97de-2cda8e882cdf    910       1  00:20:29.312      20
# 7   7cc5fc81-d389-43bc-b42b-39736836370a   1008       1  00:23:33.136      23
# ...
