# %%
# https://github.com/probberechts/soccerdata
# C:\Users\krawc\soccerdata\data\FBref 
import soccerdata as sd
# Create scraper class instance
fbref = sd.FBref()
# Out:
# [10/07/23 18:02:58] INFO     No custom team name replacements found. You can configure these in       ]8;id=783396;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=972399;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_config.py#84\84]8;;\
#                              ~\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=901064;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=23891;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_config.py#162\162]8;;\
#                              ~\soccerdata\config\league_dict.json.
# ...

# %%
sd.FBref.available_leagues()
# Out:
# ['Big 5 European Leagues Combined',
#  'ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A']

# %%
#football-data.co.uk
mh = sd.MatchHistory(leagues="ENG-Premier League", seasons=2021)
hist = mh.read_games()
hist.head()
# Out:
# [10/07/23 10:52:33] INFO     Saving cached data to C:\Users\krawc\soccerdata\data\MatchHistory        ]8;id=282543;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=311286;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_common.py#89\89]8;;\
# c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_common.py:471: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)

# %%
# Create scraper class instance filtering on specific leagues and seasons
fbref = sd.FBref(leagues=['ENG-Premier League'], seasons=['1718', '1819'])
# Retrieve data for the specified leagues and seasons
season_stats = fbref.read_team_season_stats(stat_type='shooting')
# The following stat types are available:
#     * 'standard'
#     * 'keeper'
#     * 'keeper_adv'
#     * 'shooting'
#     * 'passing'
#     * 'passing_types'
#     * 'goal_shot_creation'
#     * 'defense'
#     * 'possession'
#     * 'playing_time'
#     * 'misc'
# Out:
# [10/07/23 10:17:54] INFO     Saving cached data to C:\Users\krawc\soccerdata\data\FBref               ]8;id=870843;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=167284;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_common.py#89\89]8;;\

# %%
fbref.read_team_match_stats(stat_type="schedule", team="Manchester City")
fbref.read_schedule()
fbref.read_lineup(match_id='db261cb0')
fbref.read_events(match_id='db261cb0')
fbref.read_shot_events(match_id='db261cb0')

# %%
season_stats
# Out:
#                                           players_used 90s Standard            \
#                                                                 Gls   Sh  SoT
# league             season team
# ENG-Premier League 1718   Arsenal                   30  38       73  589  223
#                           Bournemouth               22  38       45  462  153
#                           Brighton                  24  38       33  377  110
#                           Burnley                   24  38       35  378  126
#                           Chelsea                   26  38       60  603  210
#                           Crystal Palace            28  38       44  466  134
#                           Everton                   30  38       42  351  110
#                           Huddersfield              25  38       25  360  106
#                           Leicester City            27  38       53  417  137
#                           Liverpool                 27  38       82  635  226
# ...

# %%
# https://fbref.com/en/comps/9/Premier-League-Stats
team_stats = ["standard","keeper","keeper_adv","shooting","passing","passing_types","goal_shot_creation","defense","possession","playing_time","misc",]
fbref = sd.FBref(leagues=['ENG-Premier League'], seasons=['2324'])
# Out:
# [10/07/23 13:52:50] INFO     Saving cached data to C:\Users\krawc\soccerdata\data\FBref               ]8;id=241669;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=639109;file://c:\Users\krawc\OneDrive\Documents\code\pythons\predictor\.venv\Lib\site-packages\soccerdata\_common.py#89\89]8;;\

# %%
season_stats0 = fbref.read_team_season_stats(stat_type=team_stats[0])
season_stats0
# Out:
#                                           players_used   Age  Poss  \
#
# league             season team
# ENG-Premier League 2324   Arsenal                   22  24.9  62.1
#                           Aston Villa               23  27.0  48.6
#                           Bournemouth               23  25.7  42.9
#                           Brentford                 23  26.3  50.9
#                           Brighton                  24  27.4  62.1
#                           Burnley                   24  24.7  50.3
#                           Chelsea                   22  25.0  63.3
#                           Crystal Palace            18  27.6  43.7
#                           Everton                   23  27.7  45.6
#                           Fulham                    23  29.3  50.9
#                           Liverpool                 21  27.2  52.4
#                           Luton Town                20  27.1  37.7
# ...

# %%
season_statsM = fbref.read_team_season_stats(stat_type=team_stats[-1])
season_statsM
# Out:
#                                           players_used 90s Performance       \
#                                                                   CrdY CrdR
# league             season team
# ENG-Premier League 2324   Arsenal                   22   7          12    1
#                           Aston Villa               23   7          20    0
#                           Bournemouth               23   7          11    0
#                           Brentford                 23   7          13    0
#                           Brighton                  24   7          22    0
#                           Burnley                   24   7          15    2
#                           Chelsea                   22   7          22    1
#                           Crystal Palace            18   7          11    0
#                           Everton                   23   7          12    0
#                           Fulham                    23   7          21    2
# ...
